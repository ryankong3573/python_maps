# %%
from algorithms import reconstruct_path

came_from = {
    "A" : None,
    "B" : "A",
    "C" : "B",
    "D" : "C"
}

path = reconstruct_path(came_from,"A","D")

if path != ["A","B","C","D"]:
    print("function failed")
    print(path)
else:
    print("Success")
# Out:
# Success
